# %% [markdown]
# # Python: pandas

# %% [markdown]
# <table>
#     <tr>
#         <td><img width=200 src="https://upload.wikimedia.org/wikipedia/commons/thumb/5/51/IBM_logo.svg/800px-IBM_logo.svg.png"></td>
#         <td><img width=200 src="https://skillup.online/_next/static/media/Logo.c31d02e9.svg"></td>
#     </tr>
# <table>

# %% [markdown]
# <div style="text-align: right"><a>por </a><a href="https://www.linkedin.com/in/sheriff-data/">Manuel López Sheriff</a></div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Intro" data-toc-modified-id="Intro-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Intro</a></span></li><li><span><a href="#Instalación" data-toc-modified-id="Instalación-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Instalación</a></span></li><li><span><a href="#Estructuras-de-datos-de-pandas" data-toc-modified-id="Estructuras-de-datos-de-pandas-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Estructuras de datos de pandas</a></span><ul class="toc-item"><li><span><a href="#Series" data-toc-modified-id="Series-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Series</a></span></li><li><span><a href="#DataFrames" data-toc-modified-id="DataFrames-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>DataFrames</a></span></li></ul></li><li><span><a href="#Cargar-datos-desde-un-archivo" data-toc-modified-id="Cargar-datos-desde-un-archivo-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Cargar datos desde un archivo</a></span><ul class="toc-item"><li><span><a href="#.csv" data-toc-modified-id=".csv-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>.csv</a></span></li><li><span><a href="#.xlsx" data-toc-modified-id=".xlsx-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>.xlsx</a></span></li></ul></li><li><span><a href="#Explorando-un-dataframe" data-toc-modified-id="Explorando-un-dataframe-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Explorando un dataframe</a></span></li><li><span><a href="#Explorando-por-columna" data-toc-modified-id="Explorando-por-columna-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Explorando por columna</a></span></li><li><span><a href="#Selección-dentro-del-dataframe" data-toc-modified-id="Selección-dentro-del-dataframe-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Selección dentro del dataframe</a></span><ul class="toc-item"><li><span><a href="#por-nombre-de-columna" data-toc-modified-id="por-nombre-de-columna-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>por nombre de columna</a></span></li><li><span><a href="#por-condición" data-toc-modified-id="por-condición-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>por condición</a></span></li></ul></li><li><span><a href="#Creación-de-columnas" data-toc-modified-id="Creación-de-columnas-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Creación de columnas</a></span></li><li><span><a href="#Manejo-de-valores-nulos" data-toc-modified-id="Manejo-de-valores-nulos-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Manejo de valores nulos</a></span><ul class="toc-item"><li><span><a href="#relleno-fijo" data-toc-modified-id="relleno-fijo-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>relleno fijo</a></span></li><li><span><a href="#relleno-con-otro-método" data-toc-modified-id="relleno-con-otro-método-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>relleno con otro método</a></span></li><li><span><a href="#relleno-con-la-media" data-toc-modified-id="relleno-con-la-media-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>relleno con la media</a></span></li><li><span><a href="#borrar-columna" data-toc-modified-id="borrar-columna-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>borrar columna</a></span></li><li><span><a href="#borrar-filas" data-toc-modified-id="borrar-filas-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>borrar filas</a></span></li></ul></li><li><span><a href="#GroupBy" data-toc-modified-id="GroupBy-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>GroupBy</a></span></li><li><span><a href="#Aplicación-de-funciones" data-toc-modified-id="Aplicación-de-funciones-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Aplicación de funciones</a></span></li><li><span><a href="#Exportar-datos" data-toc-modified-id="Exportar-datos-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Exportar datos</a></span></li><li><span><a href="#Recap:-métodos-más-utilizados-de-pandas" data-toc-modified-id="Recap:-métodos-más-utilizados-de-pandas-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Recap: métodos más utilizados de pandas</a></span></li><li><span><a href="#Material-extra!" data-toc-modified-id="Material-extra!-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Material extra!</a></span></li></ul></div>

# %% [markdown]
# <img width=600 src="https://www.adictosaltrabajo.com/wp-content/uploads/2020/12/1200px-Pandas_logo.svg_.png">

# %% [markdown]
# <img width=100 src="https://i0.wp.com/webdelmaestro.com/wp-content/uploads/2020/05/Dibujo-de-oso-panda.jpg?ssl=1">

# %% [markdown]
# ## Intro

# %% [markdown]
# `pandas` es la librería de Python **más utilizada** para el análisis de datos. Es:
#  * rápida
#  * potente
#  * flexible
#  * fácil de usar
#  * de código abierto ([ver código fuente](https://github.com/pandas-dev/pandas))

# %% [markdown]
# [Documentación de pandas](https://pandas.pydata.org/docs/reference/index.html#api)

# %% [markdown]
# `pandas` nos ayuda en gran parte de nuestras actividades como Data Scientists

# %% [markdown]
# ## Instalación

# %% [markdown]
# Recuerda que cualquier texto antepuesto por `!` simula una ejecución en la consola

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ## Estructuras de datos de pandas

# %% [markdown]
# ### Series

# %% [markdown]
# Una `pd.Series` es un objeto tipo array **unidimensional** donde cada elemento tiene un nombre (índice, no necesariamente numérico)

# %%
pd.Series([7, 18, 22, 4])
# Out:
# 0     7
# 1    18
# 2    22
# 3     4
# dtype: int64

# %%
s = pd.Series([7, 18, 22, 4], index=["Juan", "Emilio", "Rosa", "Tania"])

# %%
s
# Out:
# Juan       7
# Emilio    18
# Rosa      22
# Tania      4
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# Index(['Juan', 'Emilio', 'Rosa', 'Tania'], dtype='object')

# %%
s.values
# Out:
# array([ 7, 18, 22,  4], dtype=int64)

# %%
s["Juan"]
# Out:
# 7

# %% [markdown]
# Podemos pensar en una `pd.Series` como un `dict` ordenado, pues mapea cada índice a un valor
#
# `pandas` es muy inteligente, y si tienes datos contenidos en un `dict` de Python, puedes crear una `pd.Series` fácilmente.

# %%
pop = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
pop
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
pop["Ohio"]
# Out:
# 35000

# %%
type(pop)
# Out:
# dict

# %%
pop * 1.04
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-a40a02e0fbdf> in <module>
# ----> 1 pop * 1.04
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'float'

# %%
populations = pd.Series(pop)

# %%
populations
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
type(populations)
# Out:
# pandas.core.series.Series

# %%
populations["Ohio"]
# Out:
# 35000

# %%
populations * 1.04
# Out:
# Ohio      36400.0
# Texas     73840.0
# Oregon    16640.0
# Utah       5200.0
# dtype: float64

# %%
populations + 1000
# Out:
# Ohio      36000
# Texas     72000
# Oregon    17000
# Utah       6000
# dtype: int64

# %%
populations
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
populations > 10000
# Out:
# Ohio       True
# Texas      True
# Oregon     True
# Utah      False
# dtype: bool

# %%
populations[populations > 10000]
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# dtype: int64

# %% [markdown]
# ### DataFrames

# %%
import numpy as np

# %%
# desde un diccionario
data = {
    'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
    'year': [2000, 2001, 2002, 2001, 2002, 2003],
    'pop': [1.5, 1.7, 3.6, 2.4, 2.9, np.nan]
}

# %%
type(data)
# Out:
# dict

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  NaN

# %%
# desde una lista de diccionarios
datos = [
    {
        'nombre': 'Fer',
        'apellido': 'Castro',
        'email': 'fer.castro@gmail.com',
        'edad': 30,
    }, 
    {
        'nombre': 'Ana',
        'apellido': 'García',
        'email': 'ana.garcia@hotmail.com',
        'edad': 34,
    },
    {
        'nombre': 'Juan',
        'apellido': 'Lopez',
        'email': 'juan.lopez@gmail.com',
        'edad': 26,
    }
]

# %%
type(datos)
# Out:
# list

# %%
len(datos)
# Out:
# 3

# %%
df2 = pd.DataFrame(datos)

# %%
df2
# Out:
#   nombre apellido                   email  edad
# 0    Fer   Castro    fer.castro@gmail.com    30
# 1    Ana   García  ana.garcia@hotmail.com    34
# 2   Juan    Lopez    juan.lopez@gmail.com    26

# %% [markdown]
# ## Cargar datos desde un archivo

# %% [markdown]
# Pandas puede leer y escribir datos de una gran variedad de formatos.
#
# [Documentación](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html)

# %% [markdown]
# ### .csv

# %%
df = pd.read_csv("../datasets/titanic.csv")

# %%
df.shape
# Out:
# (1309, 11)

# %%
df.head()
# Out:
#                       Name     Sex   Age  Pclass  SibSp  Parch       Ticket  \
# 0        Karaic, Mr. Milan    male  30.0       3      0      0       349246
# 1       Dean, Mrs. Bertram  female  33.0       3      1      2    C.A. 2315
# 2       Rice, Mrs. William  female  39.0       3      0      5       382652
# 3  Davidson, Mrs. Thornton  female  27.0       1      1      2   F.C. 12750
# 4     Ridsdale, Miss. Lucy  female  50.0       2      0      0  W./C. 14258
#
#       Fare Cabin Embarked  Survived
# 0   7.8958   NaN        S         0
# 1  20.5750   NaN        S         1
# 2  29.1250   NaN        Q         0
# 3  52.0000   B71        S         1
# 4  10.5000   NaN        S         1

# %% [markdown]
# ### .xlsx

# %%
cars = pd.read_excel("../datasets/cars.xlsx", engine='openpyxl')

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ## Explorando un dataframe

# %%
cars.shape
# Out:
# (398, 9)

# %%
cars.head(6)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
# 5  15.0          8         429.0        198    4341          10.0        70.0
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino
# 5       1           ford galaxie 500

# %%
cars.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin         car name
# 393        82.0       1  ford mustang gl
# 394        82.0       2        vw pickup
# 395        82.0       1    dodge rampage
# 396        82.0       1      ford ranger
# 397        82.0       1       chevy s-10

# %%
cars.sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 45   18.0          6         258.0        110    2962          13.5
# 295  35.7          4          98.0         80    1915          14.4
# 9    15.0          8         390.0        190    3850           8.5
# 197  29.0          4          90.0         70    1937          14.2
# 208  13.0          8         318.0        150    3940          13.2
#
#      model year  origin                     car name
# 45         71.0       1   amc hornet sportabout (sw)
# 295        79.0       1  dodge colt hatchback custom
# 9          70.0       1           amc ambassador dpl
# 197        76.0       2                    vw rabbit
# 208        76.0       1   plymouth volare premier v8

# %%
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
for col in cars.columns:
    print(col.upper())
# Out:
# MPG
# CYLINDERS
# DISPLACEMENT
# HORSEPOWER
# WEIGHT
# ACCELERATION
# MODEL YEAR
# ORIGIN
# CAR NAME

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year      float64
# origin            int64
# car name         object
# dtype: object

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    393.000000   398.000000    396.000000
# mean    23.514573    5.454774    192.609415  2970.424623     15.559596
# std      7.815984    1.701004    103.547981   846.841774      2.752358
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.750000     13.800000
# 50%     23.000000    4.000000    146.000000  2803.500000     15.500000
# 75%     29.000000    8.000000    260.000000  3608.000000     17.125000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  396.000000  398.000000
# mean    76.035354    1.572864
# std      3.689707    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# ## Explorando por columna

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars["mpg"]
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
cars.mpg
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
cars.mpg.max()
# Out:
# 46.6

# %%
cars.mpg.min()
# Out:
# 9.0

# %%
cars.mpg.mean()
# Out:
# 23.514572864321607

# %%
cars.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    393.000000   398.000000    396.000000
# mean    23.514573    5.454774    192.609415  2970.424623     15.559596
# std      7.815984    1.701004    103.547981   846.841774      2.752358
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.000000  2223.750000     13.800000
# 50%     23.000000    4.000000    146.000000  2803.500000     15.500000
# 75%     29.000000    8.000000    260.000000  3608.000000     17.125000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  396.000000  398.000000
# mean    76.035354    1.572864
# std      3.689707    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
cars.acceleration.quantile(0.9)
# Out:
# 19.0

# %%
cars.weight.sum() // 1000
# Out:
# 1182

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars.cylinders.value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
cars.cylinders.value_counts().sort_index()
# Out:
# 3      4
# 4    204
# 5      3
# 6     84
# 8    103
# Name: cylinders, dtype: int64

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars.sort_values("mpg")
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 28    9.0          8         304.0        193    4732          18.5
# 25   10.0          8         360.0        215    4615           NaN
# 26   10.0          8           NaN        200    4376          15.0
# 103  11.0          8         400.0        150    4997          14.0
# 124  11.0          8         350.0        180    3664          11.0
# ..    ...        ...           ...        ...     ...           ...
# 326  43.4          4          90.0         48    2335          23.7
# 394  44.0          4          97.0         52    2130          24.6
# 325  44.3          4          90.0         48    2085          21.7
# 329  44.6          4          91.0         67    1850          13.8
# 322  46.6          4          86.0         65    2110          17.9
#
#      model year  origin              car name
# 28         70.0       1              hi 1200d
# 25         70.0       1             ford f250
# ...

# %%
cars.sort_values("mpg", ascending=False).head()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 322  46.6          4          86.0         65    2110          17.9
# 329  44.6          4          91.0         67    1850          13.8
# 325  44.3          4          90.0         48    2085          21.7
# 394  44.0          4          97.0         52    2130          24.6
# 326  43.4          4          90.0         48    2335          23.7
#
#      model year  origin              car name
# 322        80.0       3             mazda glc
# 329        80.0       3   honda civic 1500 gl
# 325        80.0       2  vw rabbit c (diesel)
# 394        82.0       2             vw pickup
# 326        80.0       2    vw dasher (diesel)

# %%
cars.cylinders.unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
cars.shape
# Out:
# (398, 9)

# %%
for colname in cars.columns:
    col = cars[colname]
    print(f"{colname:<16}: {col.nunique()}")
# Out:
# mpg             : 129
# cylinders       : 5
# displacement    : 81
# horsepower      : 94
# weight          : 351
# acceleration    : 95
# model year      : 13
# origin          : 3
# car name        : 305

# %% [markdown]
# Para contar pares de variables

# %%
cars.cylinders.value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
pd.crosstab(cars.cylinders, cars.origin)
# Out:
# origin       1   2   3
# cylinders
# 3            0   0   4
# 4           72  63  69
# 5            0   3   0
# 6           74   4   6
# 8          103   0   0

# %% [markdown]
# ## Selección dentro del dataframe

# %%
cars.shape
# Out:
# (398, 9)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### por nombre de columna

# %%
cars[['mpg', 'cylinders', 'displacement']].head()
# Out:
#     mpg  cylinders  displacement
# 0  18.0          8         307.0
# 1  15.0          8         350.0
# 2  18.0          8           NaN
# 3  16.0          8         304.0
# 4  17.0          8         302.0

# %% [markdown]
# ### por condición

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars.mpg > 16
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 393     True
# 394     True
# 395     True
# 396     True
# 397     True
# Name: mpg, Length: 398, dtype: bool

# %%
(cars.mpg > 16).sum()
# Out:
# 311

# %%
cars[cars.acceleration == 11]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 2    18.0          8           NaN        150    3436          11.0
# 67   11.0          8         429.0        208    4633          11.0
# 94   13.0          8         440.0        215    4735          11.0
# 95   12.0          8         455.0        225    4951          11.0
# 96   13.0          8         360.0        175    3821          11.0
# 121  15.0          8         318.0        150    3399          11.0
# 124  11.0          8         350.0        180    3664          11.0
#
#      model year  origin                      car name
# 2          70.0       1            plymouth satellite
# 67         72.0       1               mercury marquis
# 94         73.0       1  chrysler new yorker brougham
# 95         73.0       1      buick electra 225 custom
# 96         73.0       1       amc ambassador brougham
# 121        73.0       1             dodge dart custom
# ...

# %%
cars[cars.mpg > 16].head(10)
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0   18.0          8         307.0        130    3504          12.0
# 2   18.0          8           NaN        150    3436          11.0
# 4   17.0          8         302.0        140    3449          10.5
# 14  24.0          4         113.0         95    2372          15.0
# 15  22.0          6         198.0         95    2833          15.5
# 16  18.0          6         199.0         97    2774          15.5
# 17  21.0          6         200.0         85    2587          16.0
# 18  27.0          4          97.0         88    2130          14.5
# 19  26.0          4          97.0         46    1835           NaN
# 20  25.0          4           NaN         87    2672          17.5
#
#     model year  origin                      car name
# 0         70.0       1     chevrolet chevelle malibu
# 2         70.0       1            plymouth satellite
# 4         70.0       1                   ford torino
# ...

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars["car name"].str.contains("ford")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 393     True
# 394    False
# 395    False
# 396     True
# 397    False
# Name: car name, Length: 398, dtype: bool

# %%
cars[cars["car name"].str.contains("ford")].head()
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 4   17.0          8         302.0        140    3449          10.5
# 5   15.0          8         429.0        198    4341          10.0
# 17  21.0          6         200.0         85    2587          16.0
# 25  10.0          8         360.0        215    4615           NaN
# 32  25.0          4           NaN          ?    2046          19.0
#
#     model year  origin          car name
# 4         70.0       1       ford torino
# 5         70.0       1  ford galaxie 500
# 17        70.0       1     ford maverick
# 25        70.0       1         ford f250
# 32        71.0       1        ford pinto

# %%
cars[cars["car name"].str.contains("ford")].shape
# Out:
# (51, 9)

# %% [markdown]
# `~` es la negación lógica, lo contrario

# %%
cars[~cars["car name"].str.contains("ford")].shape
# Out:
# (347, 9)

# %%
cars[~cars["car name"].str.contains("ford")].head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 6  14.0          8         454.0        220    4354           9.0        70.0
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 6       1           chevrolet impala

# %% [markdown]
# `&` es el "and"
# `|` es el "or"

# %%
cars[(cars.mpg > 15) & (cars.weight > 3500)].head()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 66   17.0          8         304.0        150    3672          11.5
# 116  16.0          8         400.0        230    4278           9.5
# 133  16.0          6         250.0        100    3781          17.0
# 134  16.0          6         258.0        110    3632          18.0
#
#      model year  origin                           car name
# 0          70.0       1          chevrolet chevelle malibu
# 66         72.0       1                 amc ambassador sst
# 116        73.0       1                 pontiac grand prix
# 133        74.0       1  chevrolet chevelle malibu classic
# 134        74.0       1                        amc matador

# %%
cars[(cars.mpg > 18) | (cars.weight > 3500)].sample(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 254  20.2          6         200.0         85    2965          15.8
# 305  28.4          4         151.0         90    2670          16.0
# 31   25.0          4         113.0         95    2228          14.0
# 228  18.5          6         250.0         98    3525          19.0
# 17   21.0          6         200.0         85    2587          16.0
#
#      model year  origin               car name
# 254        78.0       1   ford fairmont (auto)
# 305        79.0       1  buick skylark limited
# 31          NaN       3          toyota corona
# 228        77.0       1           ford granada
# 17         70.0       1          ford maverick

# %%
cars[cars.cylinders.isin([3, 5])]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 71   19.0          3          70.0         97    2330          13.5
# 111  18.0          3          70.0         90    2124          13.5
# 243  21.5          3          80.0        110    2720          13.5
# 274  20.3          5         131.0        103    2830          15.9
# 297  25.4          5         183.0         77    3530          20.1
# 327  36.4          5         121.0         67    2950          19.9
# 334  23.7          3          70.0        100    2420          12.5
#
#      model year  origin             car name
# 71         72.0       3      mazda rx2 coupe
# 111        73.0       3            maxda rx3
# 243        77.0       3           mazda rx-4
# 274        78.0       2            audi 5000
# 297        79.0       2   mercedes benz 300d
# 327        80.0       2  audi 5000s (diesel)
# 334        80.0       3        mazda rx-7 gs

# %%
cars[cars.acceleration > cars.acceleration.mean()][["mpg", "acceleration", "car name"]]
# Out:
#       mpg  acceleration          car name
# 17   21.0          16.0     ford maverick
# 20   25.0          17.5       peugeot 504
# 22   25.0          17.5          saab 99e
# 28    9.0          18.5          hi 1200d
# 32   25.0          19.0        ford pinto
# ..    ...           ...               ...
# 392  27.0          17.3  chevrolet camaro
# 393  27.0          15.6   ford mustang gl
# 394  44.0          24.6         vw pickup
# 396  28.0          18.6       ford ranger
# 397  31.0          19.4        chevy s-10
#
# [183 rows x 3 columns]

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ## Creación de columnas

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars["is_fast"] = cars.acceleration > 22

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name  is_fast
# 0       1  chevrolet chevelle malibu    False
# 1       1          buick skylark 320    False
# 2       1         plymouth satellite    False
# 3       1              amc rebel sst    False
# 4       1                ford torino    False

# %%
cars["miles_per_liter"] = (cars["mpg"] / 4.54).round(2)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name  is_fast  miles_per_liter
# 0       1  chevrolet chevelle malibu    False             3.96
# 1       1          buick skylark 320    False             3.30
# 2       1         plymouth satellite    False             3.96
# 3       1              amc rebel sst    False             3.52
# 4       1                ford torino    False             3.74

# %%
cars[cars.is_fast]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 59   23.0          4          97.0         54    2254          23.5
# 195  29.0          4          85.0         52    2035          22.2
# 196  24.5          4          98.0         60    2164          22.1
# 299  27.2          4         141.0         71    3190          24.8
# 300  23.9          8         260.0         90    3420          22.2
# 326  43.4          4          90.0         48    2335          23.7
# 394  44.0          4          97.0         52    2130          24.6
#
#      model year  origin                           car name  is_fast  \
# 59         72.0       2                  volkswagen type 3     True
# 195        76.0       1                 chevrolet chevette     True
# 196        76.0       1                    chevrolet woody     True
# 299        79.0       2                        peugeot 504     True
# 300        79.0       1  oldsmobile cutlass salon brougham     True
# ...

# %% [markdown]
# ## Manejo de valores nulos

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name  is_fast  miles_per_liter
# 0       1  chevrolet chevelle malibu    False             3.96
# 1       1          buick skylark 320    False             3.30
# 2       1         plymouth satellite    False             3.96
# 3       1              amc rebel sst    False             3.52
# 4       1                ford torino    False             3.74

# %%
cars.isna().sum()
# Out:
# mpg                0
# cylinders          0
# displacement       5
# horsepower         1
# weight             0
# acceleration       2
# model year         2
# origin             0
# car name           0
# is_fast            0
# miles_per_liter    0
# dtype: int64

# %%
cars[cars.displacement.isna()]
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 2   18.0          8           NaN        150    3436          11.0
# 8   14.0          8           NaN        225    4425          10.0
# 20  25.0          4           NaN         87    2672          17.5
# 26  10.0          8           NaN        200    4376          15.0
# 32  25.0          4           NaN          ?    2046          19.0
#
#     model year  origin            car name  is_fast  miles_per_liter
# 2         70.0       1  plymouth satellite    False             3.96
# 8         70.0       1    pontiac catalina    False             3.08
# 20        70.0       2         peugeot 504    False             5.51
# 26        70.0       1           chevy c20    False             2.20
# 32        71.0       1          ford pinto    False             5.51

# %%
cars.isna().any()
# Out:
# mpg                False
# cylinders          False
# displacement        True
# horsepower          True
# weight             False
# acceleration        True
# model year          True
# origin             False
# car name           False
# is_fast            False
# miles_per_liter    False
# dtype: bool

# %%
cars.isna().any(axis=1)
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Length: 398, dtype: bool

# %%
cars[cars.isna().any(axis=1)]
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 2   18.0          8           NaN        150    3436          11.0
# 8   14.0          8           NaN        225    4425          10.0
# 12  15.0          8         400.0        NaN    3761           9.5
# 19  26.0          4          97.0         46    1835           NaN
# 20  25.0          4           NaN         87    2672          17.5
# 25  10.0          8         360.0        215    4615           NaN
# 26  10.0          8           NaN        200    4376          15.0
# 31  25.0          4         113.0         95    2228          14.0
# 32  25.0          4           NaN          ?    2046          19.0
# 38  14.0          8         350.0        165    4209          12.0
#
#     model year  origin                      car name  is_fast  miles_per_liter
# 2         70.0       1            plymouth satellite    False             3.96
# ...

# %% [markdown]
# ¿Qué hacemos? Podemos rellenar

# %% [markdown]
# ### relleno fijo

# %%
cars = cars.sort_index()

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name  is_fast  miles_per_liter
# 0       1  chevrolet chevelle malibu    False             3.96
# 1       1          buick skylark 320    False             3.30
# 2       1         plymouth satellite    False             3.96
# 3       1              amc rebel sst    False             3.52
# 4       1                ford torino    False             3.74

# %%
cars.fillna(0).head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           0.0        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name  is_fast  miles_per_liter
# 0       1  chevrolet chevelle malibu    False             3.96
# 1       1          buick skylark 320    False             3.30
# 2       1         plymouth satellite    False             3.96
# 3       1              amc rebel sst    False             3.52
# 4       1                ford torino    False             3.74

# %% [markdown]
# ### relleno con otro método

# %%
cars.fillna(method="ffill").head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8         350.0        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name  is_fast  miles_per_liter
# 0       1  chevrolet chevelle malibu    False             3.96
# 1       1          buick skylark 320    False             3.30
# 2       1         plymouth satellite    False             3.96
# 3       1              amc rebel sst    False             3.52
# 4       1                ford torino    False             3.74

# %% [markdown]
# ### relleno con la media

# %%
cars.fillna(cars.mean()).head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8    307.000000        130    3504          12.0        70.0
# 1  15.0          8    350.000000        165    3693          11.5        70.0
# 2  18.0          8    192.609415        150    3436          11.0        70.0
# 3  16.0          8    304.000000        150    3433          12.0        70.0
# 4  17.0          8    302.000000        140    3449          10.5        70.0
#
#    origin                   car name  is_fast  miles_per_liter
# 0       1  chevrolet chevelle malibu    False             3.96
# 1       1          buick skylark 320    False             3.30
# 2       1         plymouth satellite    False             3.96
# 3       1              amc rebel sst    False             3.52
# 4       1                ford torino    False             3.74

# %% [markdown]
# ### borrar columna

# %% [markdown]
# Es un poco bestia

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name  is_fast  miles_per_liter
# 0       1  chevrolet chevelle malibu    False             3.96
# 1       1          buick skylark 320    False             3.30
# 2       1         plymouth satellite    False             3.96
# 3       1              amc rebel sst    False             3.52
# 4       1                ford torino    False             3.74

# %%
cars.dropna(axis=1).head()
# Out:
#     mpg  cylinders  weight  origin                   car name  is_fast  \
# 0  18.0          8    3504       1  chevrolet chevelle malibu    False
# 1  15.0          8    3693       1          buick skylark 320    False
# 2  18.0          8    3436       1         plymouth satellite    False
# 3  16.0          8    3433       1              amc rebel sst    False
# 4  17.0          8    3449       1                ford torino    False
#
#    miles_per_liter
# 0             3.96
# 1             3.30
# 2             3.96
# 3             3.52
# 4             3.74

# %%
cars.drop("displacement", axis=1).head()
# Out:
#     mpg  cylinders horsepower  weight  acceleration  model year  origin  \
# 0  18.0          8        130    3504          12.0        70.0       1
# 1  15.0          8        165    3693          11.5        70.0       1
# 2  18.0          8        150    3436          11.0        70.0       1
# 3  16.0          8        150    3433          12.0        70.0       1
# 4  17.0          8        140    3449          10.5        70.0       1
#
#                     car name  is_fast  miles_per_liter
# 0  chevrolet chevelle malibu    False             3.96
# 1          buick skylark 320    False             3.30
# 2         plymouth satellite    False             3.96
# 3              amc rebel sst    False             3.52
# 4                ford torino    False             3.74

# %% [markdown]
# ### borrar filas

# %%
cars[cars.displacement.notna()].head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
# 5  15.0          8         429.0        198    4341          10.0        70.0
#
#    origin                   car name  is_fast  miles_per_liter
# 0       1  chevrolet chevelle malibu    False             3.96
# 1       1          buick skylark 320    False             3.30
# 3       1              amc rebel sst    False             3.52
# 4       1                ford torino    False             3.74
# 5       1           ford galaxie 500    False             3.30

# %%
cars.dropna(axis=0).head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
# 5  15.0          8         429.0        198    4341          10.0        70.0
#
#    origin                   car name  is_fast  miles_per_liter
# 0       1  chevrolet chevelle malibu    False             3.96
# 1       1          buick skylark 320    False             3.30
# 3       1              amc rebel sst    False             3.52
# 4       1                ford torino    False             3.74
# 5       1           ford galaxie 500    False             3.30

# %% [markdown]
# ## GroupBy

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name  is_fast  miles_per_liter
# 0       1  chevrolet chevelle malibu    False             3.96
# 1       1          buick skylark 320    False             3.30
# 2       1         plymouth satellite    False             3.96
# 3       1              amc rebel sst    False             3.52
# 4       1                ford torino    False             3.74

# %%
cars.groupby('cylinders').acceleration.mean().round(2)
# Out:
# cylinders
# 3    13.25
# 4    16.58
# 5    18.63
# 6    16.26
# 8    12.95
# Name: acceleration, dtype: float64

# %%
cars.groupby('model year').mpg.mean().round(1)
# Out:
# model year
# 70.0    17.7
# 71.0    21.4
# 72.0    18.7
# 73.0    17.1
# 74.0    22.7
# 75.0    20.3
# 76.0    21.6
# 77.0    23.4
# 78.0    24.1
# 79.0    25.1
# 80.0    33.7
# 81.0    30.3
# 82.0    31.7
# Name: mpg, dtype: float64

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8           NaN        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name  is_fast  miles_per_liter
# ...

# %% [markdown]
# ## Aplicación de funciones

# %% [markdown]
# Utilizamos el método `apply`

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name  is_fast  miles_per_liter
# 0       1  chevrolet chevelle malibu    False             3.96
# 1       1          buick skylark 320    False             3.30
# 2       1         plymouth satellite    False             3.96
# 3       1              amc rebel sst    False             3.52
# 4       1                ford torino    False             3.74

# %% [markdown]
# Imaginemos que queremos computar, para cada coche:
#  * la primera palabra del nombre
#  * si el año del modelo fue bisiesto

# %% [markdown]
# Primero creamos la función, luego la aplicamos

# %%
def get_first_word(sentence):
    words = sentence.split()
    
    return words[0]

# %%
get_first_word("hola me llamo manuel")
# Out:
# 'hola'

# %%
def is_bisiest(year):
    if year % 4 == 0:
        return True
    else:
        return False

# %%
is_bisiest(2001)
# Out:
# False

# %%
cars["is_bisiest"] = cars["model year"].apply(is_bisiest)

# %%
cars["name1"] = cars["car name"].apply(get_first_word)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name  is_fast  miles_per_liter  is_bisiest  \
# 0       1  chevrolet chevelle malibu    False             3.96       False
# 1       1          buick skylark 320    False             3.30       False
# 2       1         plymouth satellite    False             3.96       False
# 3       1              amc rebel sst    False             3.52       False
# 4       1                ford torino    False             3.74       False
#
#        name1
# 0  chevrolet
# 1      buick
# ...

# %% [markdown]
# ## Exportar datos

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0        70.0
# 1  15.0          8         350.0        165    3693          11.5        70.0
# 2  18.0          8           NaN        150    3436          11.0        70.0
# 3  16.0          8         304.0        150    3433          12.0        70.0
# 4  17.0          8         302.0        140    3449          10.5        70.0
#
#    origin                   car name  is_fast  miles_per_liter  is_bisiest  \
# 0       1  chevrolet chevelle malibu    False             3.96       False
# 1       1          buick skylark 320    False             3.30       False
# 2       1         plymouth satellite    False             3.96       False
# 3       1              amc rebel sst    False             3.52       False
# 4       1                ford torino    False             3.74       False
#
#        name1
# 0  chevrolet
# 1      buick
# ...

# %%
cars.to_csv('../datasets/cars1111.csv', index=False)

# %%
cars.to_csv('../datasets/cars2.csv', index=True)

# %%
cars.to_json('../datasets/cars2222.json', orient='records')

# %%
cars.to_excel('../datasets/cars.xlsx', index=False)

# %% [markdown]
# ## Recap: métodos más utilizados de pandas

# %% [markdown]
# ```python
# df.head()                     # printea la cabeza, por defecto 5 filas
# df.tail()                     # pritea la cola, por defecto 5 filas
# df.describe()                 # descripcion estadistica
# df.info()                     # informacion del df
# df.info(memory_usage='deep')
# df.columns                    # muestra columna
# df.index                      # muestra indice
# df.dtypes                     # muestra tipos de datos de las columnas
# df.plot()                     # hace un grafico
# df.hist()                     # hace un histograma
# df.col.value_counts()         # cuenta los valores unicos de una columna
# df.col.unique()               # muestra valores unicos de una columna
# df.copy()                     # copia el df
# df.drop()                     # elimina columnas o filas (axis=0,1)
# df.dropna()                   # elimina nulos
# df.fillna()                   # rellena nulos
# df.shape                      # dimensiones del df
# df._get_numeric_data()        # selecciona columnas numericas
# df.rename()                   # renombre columnas
# df.str.replace()              # reemplaza columnas de strings
# df.astype(dtype='float32')    # cambia el tipo de dato
# df.iloc[]                     # localiza por indice
# df.loc[]                      # localiza por elemento
# df.transpose()                # transpone el df
# df.T
# df.sample(n, frac)            # muestra del df
# df.col.sum()                  # suma de una columna
# df.col.max()                  # maximo de una columna
# df.col.min()                  # minimo de una columna
# df[col]                       # selecciona columna
# df.col
# df.isnull()                   # valores nulos
# df.isna()
# df.notna()                    # valores no nulos
# df.drop_duplicates()          # eliminar duplicados
# df.reset_index(inplace=True)  # resetea el indice y sobreescribe
# ```

# %% [markdown]
# ## Material extra!

# %% [markdown]
# * [Cheatsheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# * [Ejercicios para practicar](https://github.com/guipsamora/pandas_exercises)
# * [merge, concat, join](https://realpython.com/pandas-merge-join-and-concat/#pandas-join-combining-data-on-a-column-or-index)
